# %%
import requests
import json
import pandas as pd

# %%
url = 'http://ecshweb.pchome.com.tw/search/v3.3/all/results?q=sony&page=1&sort=rnk/dc' 
res = requests.get(url)
data = json.loads(res.text)

# %%
data
# Out:
# {'QTime': 58,
#  'cateName': '',
#  'prods': [{'Id': 'DGBQ1I-A900567F7',
#    'author': '',
#    'brand': '',
#    'cateId': 'DGBQ36',
#    'couponActid': [],
#    'describe': '送專用電SONY A5000L 單機身 中文平輸',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY ILCE-5000 單機身 中文平輸',
#    'originPrice': 8990,
#    'picB': '/items/DGBQ1IA900567F7/000001_1493949966.jpg',
#    'picS': '/items/DGBQ1IA900567F7/000002_1478319535.jpg',
#    'price': 8990,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DYAD3I-19008NLJ7',
#    'author': '',
#    'brand': '',
#    'cateId': 'DYAD3I',
#    'couponActid': [],
#    'describe': '★下殺超低價SONY XPERIA XZ-山茶花粉',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY XPERIA XZ-山茶花粉',
#    'originPrice': 9499,
#    'picB': '/items/DYAD3I19008NLJ7/000001_1519613616.jpg',
#    'picS': '/items/DYAD3I19008NLJ7/000002_1514513698.jpg',
#    'price': 9499,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DYAD3N-A90080QZV',
#    'author': '',
#    'brand': '',
#    'cateId': 'DYAD3N',
#    'couponActid': [],
#    'describe': '◤送玻璃保貼+TYPE-C線+立架◢Sony Xperia XA1 (3G/32G) 八核心5吋智慧機',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY XPERIA XA1',
#    'originPrice': 5580,
#    'picB': '/items/DYAD3NA90080QZV/000001_1491547112.jpg',
#    'picS': '/items/DYAD3NA90080QZV/000002_1491547112.jpg',
#    'price': 5580,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DYAD4J-A9008E39C',
#    'author': '',
#    'brand': '',
#    'cateId': 'DYAD4J',
#    'couponActid': [],
#    'describe': '★贈玻璃貼＋保護套★ SONY XPERIA XZ1',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY XPERIA XZ1',
#    'originPrice': 15380,
#    'picB': '/items/DYAD4JA9008E39C/000001_1520218941.jpg',
#    'picS': '/items/DYAD4JA9008E39C/000002_1505215868.jpg',
#    'price': 15380,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DPAD06-A9008BPFP',
#    'author': '',
#    'brand': '',
#    'cateId': 'DPAD06',
#    'couponActid': [],
#    'describe': 'SONY 55吋 4K HDR連網液晶電視 KD-55X7000E★超極真影像晶片★極瞬流線影像240Hz★低音反射箱型喇叭',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY 55型 4K+HDR 液晶電視 KD-55X7000E',
#    'originPrice': 33155,
#    'picB': '/items/DPAD06A9008BPFP/000001_1519612562.jpg',
#    'picS': '/items/DPAD06A9008BPFP/000002_1519612562.jpg',
#    'price': 33155,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DYAD4V-A9008G6UF',
#    'author': '',
#    'brand': '',
#    'cateId': 'DYAD4V',
#    'couponActid': [],
#    'describe': '★贈保護套★SONY XPERIA XA1 Plus',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY XPERIA XA1 Plus',
#    'originPrice': 7888,
#    'picB': '/items/DYAD4VA9008G6UF/000001_1519382369.jpg',
#    'picS': '/items/DYAD4VA9008G6UF/000002_1506928728.png',
#    'price': 7888,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DGBJA8-A90084NVG',
#    'author': '',
#    'brand': '',
#    'cateId': 'DGBJA8',
#    'couponActid': [],
#    'describe': 'SONY  無線立體聲耳罩耳機CECHYA-0083(支援7.1聲道)',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY PS4 無線立體聲耳機',
#    'originPrice': 2980,
#    'picB': '/items/DGBJA8A90084NVG/000001_1495159305.png',
#    'picS': '/items/DGBJA8A90084NVG/000002_1495159305.png',
#    'price': 2980,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DGBQ1H-A9005RUHR',
#    'author': '',
#    'brand': '',
#    'cateId': 'DGBQ32',
#    'couponActid': [],
#    'describe': '▼64G豪華電充組▼SONY ILCE-7M2K 單鏡組 公司貨',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY ILCE-7M2K單鏡組 (公司貨)',
#    'originPrice': 51980,
#    'picB': '/items/DGBQ1HA9005RUHR/000001_1519868516.jpg',
#    'picS': '/items/DGBQ1HA9005RUHR/000002_1478385557.jpg',
#    'price': 51980,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DPAE03-A9007MIYA',
#    'author': '',
#    'brand': '',
#    'cateId': 'DPAE03',
#    'couponActid': [],
#    'describe': '▼送原廠雙好禮▼新一代SONY MP-CL1A 行動微型投影機',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY MP-CL1A 行動微型投影機',
#    'originPrice': 12900,
#    'picB': '/items/DPAE03A9007MIYA/000001_1519870924.jpg',
#    'picS': '/items/DPAE03A9007MIYA/000002_1479376516.jpg',
#    'price': 12900,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DCAIDH-A90084GL6',
#    'author': '',
#    'brand': '',
#    'cateId': 'DCAIDH',
#    'couponActid': [],
#    'describe': '★新品上市★SONY SRS-XB10 可攜式防潑灑藍牙喇叭(公司貨)',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY SRS-XB10 可攜式防潑灑藍牙喇叭',
#    'originPrice': 1790,
#    'picB': '/items/DCAIDHA90084GL6/000001_1495000387.jpg',
#    'picS': '/items/DCAIDHA90084GL6/000002_1495000387.jpg',
#    'price': 1790,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DYAD4Z-A9008QR8K',
#    'author': '',
#    'brand': '',
#    'cateId': 'DYAD4Z',
#    'couponActid': [],
#    'describe': '6吋大螢幕★送行電+LED夜燈SONY XPERIA XA2 Ultra',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY XPERIA XA2 Ultra',
#    'originPrice': 14990,
#    'picB': '/items/DYAD4ZA9008QR8K/000001_1519611769.jpg',
#    'picS': '/items/DYAD4ZA9008QR8K/000002_1517890041.jpg',
#    'price': 14990,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'QAAC0K-A9008J408',
#    'author': '',
#    'brand': '',
#    'cateId': 'QAAC0K',
#    'couponActid': [],
#    'describe': '【門市拆封福利品】SONY Xperia Tablet Z 平板電腦(SGP311)',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': '【SONY福利品】SONY Xperia Tablet Z 16G WIFI平板電腦',
#    'originPrice': 4690,
#    'picB': '/items/QAAC0KA9008J408/000001_1510210423.jpg',
#    'picS': '/items/QAAC0KA9008J408/000002_1510210423.jpg',
#    'price': 4690,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DGBJA8-A9007T4US',
#    'author': '',
#    'brand': '',
#    'cateId': 'DGBJA8',
#    'couponActid': [],
#    'describe': 'SONY PS4原廠 3D環繞音效 7.1虛擬聲道 無線耳罩耳機組 CECHYA-0090',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY 3D環繞無線耳機(CECHYA-0090)',
#    'originPrice': 4980,
#    'picB': '/items/DGBJA8A9007T4US/000001_1487915756.jpg',
#    'picS': '/items/DGBJA8A9007T4US/000002_1487915756.jpg',
#    'price': 4980,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DYAD4X-A9008QNBO',
#    'author': '',
#    'brand': '',
#    'cateId': 'DYAD4X',
#    'couponActid': [],
#    'describe': '送行動電源+32G卡+保護套＋玻璃貼SONY XPERIA XA2 (3G/32G)',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY XPERIA XA2',
#    'originPrice': 10990,
#    'picB': '/items/DYAD4XA9008QNBO/000001_1516868493.jpg',
#    'picS': '/items/DYAD4XA9008QNBO/000002_1516868493.jpg',
#    'price': 10990,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DYAD4V-A9008I1OI',
#    'author': '',
#    'brand': '',
#    'cateId': 'DYAD4V',
#    'couponActid': [],
#    'describe': '★超值熱銷機SONY XPERIA XA1 Plus',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY XPERIA XA1 Plus',
#    'originPrice': 7790,
#    'picB': '/items/DYAD4VA9008I1OI/000001_1519180689.jpg',
#    'picS': '/items/DYAD4VA9008I1OI/000002_1509085939.png',
#    'price': 7790,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DGBQ1H-A9006LHR6',
#    'author': '',
#    'brand': '',
#    'cateId': 'DGBQ2Z',
#    'couponActid': [],
#    'describe': '送MASSA-UV保護鏡▼32G電充組SONY A6000 16-50mm 變焦鏡組ILCE-6000L 公司貨',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY A6000 16-50mm 變焦鏡組ILCE-6000L',
#    'originPrice': 18800,
#    'picB': '/items/DGBQ1HA9006LHR6/000001_1513043766.jpg',
#    'picS': '/items/DGBQ1HA9006LHR6/000002_1476841352.jpg',
#    'price': 18800,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DYAD0D-A9008I1P1',
#    'author': '',
#    'brand': '',
#    'cateId': 'DYAD0D',
#    'couponActid': [],
#    'describe': '★送蛋黃哥手機座+線SONY XPERIA XA1 Ultra',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY XPERIA XA1 Ultra',
#    'originPrice': 8990,
#    'picB': '/items/DYAD0DA9008I1P1/000001_1516949065.jpg',
#    'picS': '/items/DYAD0DA9008I1P1/000002_1509086091.jpg',
#    'price': 8990,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DGBQ1H-A90068G9U',
#    'author': '',
#    'brand': '',
#    'cateId': 'DGBQ32',
#    'couponActid': [],
#    'describe': '高速64G+原電▼快門線組SONY ILCE-7RM2 單機身 (公司貨) 全配組',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY ILCE-7RM2 單機身 (公司貨)',
#    'originPrice': 74880,
#    'picB': '/items/DGBQ1HA90068G9U/000001_1520213979.jpg',
#    'picS': '/items/DGBQ1HA90068G9U/000002_1478452118.jpg',
#    'price': 74880,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DGAD81-A9007L7OQ',
#    'author': '',
#    'brand': '',
#    'cateId': 'DGAD81',
#    'couponActid': [],
#    'describe': '★送64G全配組SONY DSC-RX100M5 數位相機 (公司貨)',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY DSC-RX100M5 數位相機 (公司貨)',
#    'originPrice': 31980,
#    'picB': '/items/DGAD81A9007L7OQ/000001_1514860570.jpg',
#    'picS': '/items/DGAD81A9007L7OQ/000002_1506838381.jpg',
#    'price': 31980,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DGAD01-A90054RYV',
#    'author': '',
#    'brand': '',
#    'cateId': 'DGAD81',
#    'couponActid': [],
#    'describe': '★64G超狂三電組SONY DSC-RX100M3 數位相機 (公司貨)',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SONY DSC-RX100M3(公司貨)',
#    'originPrice': 21599,
#    'picB': '/items/DGAD01A90054RYV/000001_1516844725.jpg',
#    'picS': '/items/DGAD01A90054RYV/000002_1505097691.jpg',
#    'price': 21599,
#    'publishDate': '',
#    'sellerId': ''}],
#  'q': 'sony',
#  'range': {'max': '', 'min': ''},
#  'subq': '',
#  'token': ['sony'],
#  'totalPage': 100,
#  'totalRows': 35685}
