# %%
# Author: KBJiyu
# Date: 2017/07
# Target: scrape data from youtube
# Learning from: https://hiskio.com/course/112/lecture/3143

# 環境設定
# [cmd] pip install requests # requests 網路資源(URLs)擷取套件 
# [cmd] pip install beautifulsoup4 # beautifulSoup4 HTML剖析套件

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.youtube.com/results?search_query=%E5%91%A8%E6%9D%B0%E5%80%AB"
response = requests.get(url)
content = response.content
soup = BeautifulSoup(content, "html.parser")

for all_mv in soup.select(".yt-lockup-video"):
    # 抓取 Title & Link
    data = all_mv.select("a[rel='spf-prefetch']")
    print("名稱: {}".format(data[0].get("title")))
    print("連結: https://www.youtube.com{}".format(data[0].get("href")))

    # 抓取觀看時間與人數
    data = all_mv.select(".yt-lockup-meta-info")
    time = data[0].get_text("#").split("#")[0]
    see = data[0].get_text("#").split("#")[1]
    print("發佈時間: {}".format(time))
    print("觀看人數: {}".format(see))

    # 抓取Img
    data = all_mv.select("a[rel='spf-prefetch']")
    img = all_mv.select("img")
    if img[0].get("src") != "/yts/img/pixel-vfl3z5WfW.gif":
        print("照片: {}".format(img[0].get("src")))
    else:
        print("照片: {}".format(img[0].get("data-thumb")))
    print("-------------------")
# Out:
# 名稱: 周杰倫 Jay Chou (with 楊瑞代)【等你下課 Waiting For You】歌詞版MV
# 連結: https://www.youtube.com/watch?v=kfXdP7nZIiE
# 發佈時間: 1 個月前
# 觀看人數: 觀看次數：31,969,156
# 照片: https://i.ytimg.com/vi/kfXdP7nZIiE/hqdefault.jpg?sqp=-oaymwEXCPYBEIoBSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLAOYkSb9DeznIuNbPqXOZoW-QG3xQ
# -------------------
# 名稱: 周杰倫 2017 - 周杰倫好聽的20首歌 - 周杰倫 Jay Chou 2017 - Best Songs Of Jay Chou 2017 - 周杰倫最偉大的命中
# 連結: https://www.youtube.com/watch?v=bTT4lmzlFuE
# 發佈時間: 5 個月前
# 觀看人數: 觀看次數：4,437,313
# 照片: https://i.ytimg.com/vi/bTT4lmzlFuE/hqdefault.jpg?sqp=-oaymwEXCPYBEIoBSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDOi0CLPe_Rr0wJ3VD5aL_HY5JoKA
# -------------------
# 名稱: 周杰倫 Jay Chou (with 楊瑞代)【等你下課 Waiting For You】導演版MV
# 連結: https://www.youtube.com/watch?v=QQucPUfXUQQ
# 發佈時間: 1 週前
# 觀看人數: 觀看次數：3,672,458
# 照片: https://i.ytimg.com/vi/QQucPUfXUQQ/hqdefault.jpg?sqp=-oaymwEXCPYBEIoBSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLB2woYN0pjkUhhO0xnrvnT9LrbD_w
# -------------------
# 名稱: 周杰倫 Jay Chou (特別演出: 派偉俊)【告白氣球 Love Confession】Official MV
# 連結: https://www.youtube.com/watch?v=bu7nU9Mhpyo
# 發佈時間: 1 年前
# 觀看人數: 觀看次數：135,251,678
# 照片: https://i.ytimg.com/vi/bu7nU9Mhpyo/hqdefault.jpg?sqp=-oaymwEXCPYBEIoBSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLAE13qQbSScwkjqmq2iEUw86RvHkA
# -------------------
# 名稱: #周杰倫精選組曲 #精選抒情歌曲Jay Chou Collection
# 連結: https://www.youtube.com/watch?v=gddwCdQ1MQo
# 發佈時間: 3 個月前
# 觀看人數: 觀看次數：105,250
# 照片: https://i.ytimg.com/vi/gddwCdQ1MQo/hqdefault.jpg?sqp=-oaymwEXCPYBEIoBSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLB58ROZuziLqzQwYSzCXTJtLv5vzw
# -------------------
# 名稱: 周杰倫－魔天倫世界巡回演唱會[完整版]
# 連結: https://www.youtube.com/watch?v=d_lyiOhFut4
# 發佈時間: 1 年前
# 觀看人數: 觀看次數：1,186,597
# 照片: https://i.ytimg.com/vi/d_lyiOhFut4/hqdefault.jpg?sqp=-oaymwEXCPYBEIoBSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CL